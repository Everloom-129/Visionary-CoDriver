# %% [markdown]
# # Semantic Segment Road and Sidewalk
# Tony Wang July 04 2023
#
# After semantic segmentation of road and sidewalk, we obtain the pixel level binary mask of them. Which can be used to detect human-road relationship using rule-based comparision. Since the SAM didn't provide necessary api, I write some utility func to realize it
#
# > This notebook is used for tutuorial demo, because I believe, compared to the unstable .py file, jupyter notebook would provide a vivid description and data pipeline demonstration.

# %% [markdown]
# ## Library & Model Loading

# %%
import os
import cv2
# filter some annoying debug info
import warnings
warnings.filterwarnings('ignore')

import torch
import torchvision
import supervision as sv

import numpy as np
from PIL import Image
from pathlib import Path
from collections import Counter

import matplotlib.pyplot as plt

from groundingdino.util.inference import Model
from segment_anything import sam_model_registry, SamPredictor
#TODO name!
from groundingdino.util.inference import load_model, load_image, predict, annotate

# import SAM_utility # 

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# Paths to GroundingDINO and SAM checkpoints
GROUNDING_DINO_CONFIG_PATH = "../GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py"
GROUNDING_DINO_CHECKPOINT_PATH = "./weights/groundingdino_swint_ogc.pth"
MODEL_TYPE = "vit_b"
SAM_CHECKPOINT_PATH = "./weights/sam_vit_b_01ec64.pth"

# Predict classes and hyper-param for GroundingDINO
BOX_TRESHOLD = 0.25
TEXT_TRESHOLD = 0.25
PED_TRESHOLD = 0.5

NMS_THRESHOLD = 0.85
IOU_THRESHOLD = 0.5

# %%
DEBUG = False
# DEBUG = True

# %%
from depth_util import predict_depth,get_distance_category
from mask_util import (
    show_mask, show_points, show_box, display_mask, nms_processing, 
    is_overlap, compute_overlap, get_location, get_surface_info
)
from file_io    import is_image_file
from angle_util import describe_angle,estimate_angle

# %%
from DPT_module.dpt.models import DPTDepthModel
from DPT_module.dpt.midas_net import MidasNet_large
from DPT_module.dpt.transforms import Resize, NormalizeImage, PrepareForNet
import DPT_module.util.io as DPT_io
from torchvision.transforms import Compose

# %% [markdown]
# The model loading is quite long
# with some unremovable warning in gDINO, just ignore it

# %%
# Initialize GroundingDINO model
grounding_dino_model = Model(
    model_config_path=GROUNDING_DINO_CONFIG_PATH, 
    model_checkpoint_path=GROUNDING_DINO_CHECKPOINT_PATH, 
    device=DEVICE
)

# Initialize SAM model and predictor
sam = sam_model_registry[MODEL_TYPE](checkpoint=SAM_CHECKPOINT_PATH)
sam.to(device=DEVICE)
sam_predictor = SamPredictor(sam)
# Out:
# final text_encoder_type: bert-base-uncased

# %% [markdown]
# # Data structure
# LocationInfo: pack form to help data-alignment

# %%
class LocationInfo:
    def __init__(self, object_type, id, box, mask,confidence):
        self.object_type = object_type  # ('sidewalk', 'road', or 'person')
        self.id = id  # Unique ID within the type
        self.box = box  # Bounding box in xyxy format
        self.mask = mask  # Binary mask indicating the precise location of the object
        self.confidence = confidence #confidence of bbox
        self.distance = None # str,{very close,close, median, far, very far}
        self.dist_value = None
        self.angle = None    # horizontal angle relative to camera
    def get_area(self):
        """
        int: The area of the object in pixels.
        """
        return np.sum(self.mask)

# %% [markdown]
# ## Utility Function

# %% [markdown]
# ## Architecture:
# 1. gDINO : grounding_dino_model.predict_with_classes
#
#    CLASSES_prompt= ['road', 'sidewalk']
#
#    Based on testing, this pair is most reliable (otherwise the sidewalk may messed up with road)
#
#    In this part, I use the box as Region of Interest(ROI) to further prompt SAM
#
# 2. Non-maximum suppression (NMS) :
#
#    get rid of redundant and overlapping bounding boxes.
#
#    the metric is Intersection over Union(IoU)
#
# 3. Prompting SAM with ROI, select mask with largest area, in this step, the road and sidewalk can be segmented with naming in pixel level accuracy.
#
# 4. save the result
#
# 5. label the result with label and confidence
#
# 6. TODO: do image sequence experiment, analyze the behavior of person
#
# 7. TODO: split cases based on JAAD info
#
#    - car is moving
#    - car is stopping
#    - time
#    - weather
#    - more...
#
# In GTX3090 environment, the algorithm runs relatively fast with GPU boosting.
#
# (Not as bad as I guessed before, much faster than all of the online demo)

# %% [markdown]
# ## Location utility function
# - is_overlap: a mask-level comparitor func

# %% [markdown]
# Surface Utility Function

# %%
def obj_print(obj_dict,image):
    for name, person in obj_dict.items():
        print(name)
        print(person.box)
        print(person.distance)
        person.angle = estimate_angle(image,person)

        print(f"angle is {person.angle},it is {describe_angle(person.angle)}")
        print("\n\n")

# %%
def write_to_txt(image_path, output_path, p_surface_overlaps,obj_dict):
    """
    Writes the details of a road scene analysis into a text file. 
    The information includes:
    detected persons and the surfaces they are on, counts of various detections,
    labels for detections and people, and details about each object in the scene.
    

    Args:
        image_path (str): The relative path to the input image.
        output_path (str): The output path for the analysis results.
        p_surface_overlaps (List[Tuple[LocationInfo, List[LocationInfo]]])
        : A list of tuples where each tuple contains a person
        and a list of surfaces (as LocationInfo objects) that the person overlaps with.
        counts (Tuple[int, int, int, int]): A tuple containing counts of surface masks,
        road & sidewalk masks, people's masks, and actual people.
        labels (List[str]): A list of labels for the detected objects.
        p_labels (List[str]): A list of labels specifically for the detected persons.
        obj_dict (Dict[str, LocationInfo]) A dictionary mapping from unique entity identifiers 
        to corresponding LocationInfo objects.

    Returns & Raises:
        None
    """

    output_dir = Path(output_path).parent
    img_name = image_path[-8:-4]
    txt_name = "Info_Video_"+ str(output_dir)[-4:] +".txt"
    txt_path = os.path.join(output_dir, txt_name) 

    if DEBUG:
        print("output_dir: ", output_dir)
        print("image_name: ", img_name)
        print("txt_path: ", txt_path)
    # Check if file already exists
    if DEBUG:
        if os.path.exists(txt_path):
            # Read in existing data
            with open(txt_path, 'r') as f:
                existing_data = f.read()

            # If the info of the current image has already been recorded, return without appending
            if f"INFO of frame {img_name}:\n" in existing_data:
                print(f"ERROR: the info of{img_name} has been generated")
                return
    with open(txt_path, 'a') as f: # 'a' option is for appending to the file if it exists
        f.write(f"INFO of frame {img_name}:\n")

        get_surface_info(obj_dict,f)
        
        for person, surfaces in p_surface_overlaps:
            if surfaces:
                surface_str = ', '.join([f"{surface.object_type} {surface.id}" for surface in surfaces])
                f.write(f"Person {person.id} is on the {surface_str}, his/her bbox is{person.box}\n")
            else:
                f.write(f"Person {person.id} is not on any detected surface, his/her bbox is{person.box}\n")
                
        # f.write(f"Labels: [{', '.join(labels)}]\n")
        # f.write(f"Person Labels: [{', '.join(p_labels)}]\n\n")

# %% [markdown]
# ## Key Function

# %%
def segment_ROI(sam_predictor: SamPredictor, image: np.ndarray, boxes: np.ndarray):
    # Prompting SAM with Region of Interest
    # Return: binary mask indicating the precise shape of object

    sam_predictor.set_image(image)
    result_masks = []
    for box in boxes:
        masks_np, iou_predictions, _ = sam_predictor.predict(
        point_coords=None,
        point_labels=None,
        box=box,
        multimask_output=True,
        )
        #TODO Remove the following line to get all the person masks
        # index = np.argmax(scores_np) 
        # Add all masks to the result, not just the one with the highest score
        # Filter out masks with IoU scores below the threshold
        for mask, score in zip(masks_np, iou_predictions):
            if score >= IOU_THRESHOLD:
                result_masks.append(mask)

    return np.array(result_masks)

# %% [markdown]
# refactored version

# %%
# def get_cv2_image(image_path: str):
#     """
#     This function loads an image from a given path and converts it from BGR to RGB.

#     Args:
#     - image_path: The path to the image.

#     Returns:
#     - The converted image if successful, or None if the image could not be loaded or processed.
#     """
#     try:
#         image = cv2.imread(image_path)
#         if image is None:
#             print(f"Image at path {image_path} could not be loaded. Skipping.")
#             return None
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         return image

#     except Exception as e:
#         print(f"Failed to process image at {image_path}. Error: {e}")
#         return None

# %%
# def get_detections(image, box_threshold, text_threshold, classes):
#     """
#     This function runs the detection model and performs non-maximum suppression on the results.

#     Args:
#     - image: The input image.
#     - box_threshold: The confidence threshold for considering detection boxes.
#     - text_threshold: The confidence threshold for considering detected labels.
#     - classes: The classes to detect.

#     Returns:
#     - detections: The detected objects after non-maximum suppression.
#     """
#     detections = grounding_dino_model.predict_with_classes(
#         image=image,
#         classes=classes,
#         box_threshold=box_threshold,
#         text_threshold=text_threshold
#     )
#     detections = nms_processing(detections)

#     return detections

# def get_label_and_box(classes,detections):
    
#     labels = [
#         f"{classes[class_id]} {i} {confidence:0.2f}" 
#         for i, (_, _, confidence, class_id, _) in enumerate(detections)]
#     boxes = np.array(detections.xyxy)
#     return labels,boxes

# def get_location_info(boxes, labels, masks):
#     """
#     This function creates LocationInfo objects for the detected objects.

#     Args:
#     - boxes: The detected objects.
#     - labels: The labels for the detected objects.
#     - masks: The segmentation masks for the detected objects.
#     - object_type: The type of the objects.

#     Returns:
#     - obj_dict: A dictionary mapping from unique entity identifiers to corresponding LocationInfo objects.
#     """
#     obj_dict = dict()

#     for i, (box, label, mask) in enumerate(zip(boxes, labels, masks)):
#         object_type, id, confidence   = label.split(' ')
#         index = object_type + id
#         obj_dict[index] =  (LocationInfo(object_type, int(id), box, mask, confidence)) 

#     return obj_dict

# def analyze_person_location(obj_dict, depth_flag, image=None, depth_map=None):
#     """
#     This function analyzes where each person is standing.

#     Args:
#     - obj_dict: A dictionary of LocationInfo objects.
#     - depth_flag: A flag indicating whether to predict the depth.
#     - image: The input image.
#     - depth_map: The depth map of the scene.

#     Returns:
#     - p_surface_overlaps: A list of tuples where each tuple contains a person and the surfaces they overlap with.
#     """
#     p_surface_overlaps = []
    
#     for name, person in obj_dict.items():
#         if person.object_type != "person":
#             continue # We only want to analyze persons

#         if depth_flag:
#             person.distance = get_distance_category(depth_map,person.mask)
#             person.angle   = estimate_angle(image,person)
        
#         overlaps = []
#         for name, surface in obj_dict.items():
#             # We only want to analyze surfaces (road or sidewalk)
#             if surface.object_type not in ['road', 'sidewalk']: 
#                 continue

#             # Check if the person and the surface overlap
#             overlap, _ = is_overlap(person.mask, surface.mask)
#             if overlap:
#                 overlaps.append(surface)

#         p_surface_overlaps.append((person, overlaps))

#     return p_surface_overlaps

# %%
# def get_annotated_image(image, labels,P_labels,detections,p_detections):

#     box_annotator = sv.BoxAnnotator()
#     person_annotator = sv.BoxAnnotator()

#     annotated_frame = box_annotator.annotate(scene=image.copy(), detections=detections ,labels=labels)
#     if DEBUG:
#         sv.plot_image(annotated_frame, (16, 9))
#     person_annotation = person_annotator.annotate(scene=annotated_frame,detections= p_detections,labels= P_labels)
#     if DEBUG:
#         sv.plot_image(person_annotation, (16, 9))

#     return person_annotation

# %%
# def detect_road(image_path:str, output_path:str):
#     image = get_cv2_image(image_path)
#     if image is None:
#         print("Error when reading ",image_path)
#         return None
#     ROAD_SIDEWALK = ['road', 'sidewalk'] 
#     P_CLASS     = ['person'] #,'bike']
#     # Detect objects
#     detections = get_detections(image, BOX_TRESHOLD, TEXT_TRESHOLD,ROAD_SIDEWALK)
#     p_detections = get_detections(image, BOX_TRESHOLD, PED_TRESHOLD, P_CLASS)
#     if detections is not None:
#         labels,DINO_boxes = get_label_and_box(ROAD_SIDEWALK,detections)
#         print("no road detected")
#     if p_detections is not None:
#         P_labels, P_boxes = get_label_and_box(P_CLASS,p_detections)
#     else:
#         print("no pedestrian detected")
#     # Segment objects
#     SAM_masks = segment_ROI(sam_predictor, image, DINO_boxes)
#     P_masks = segment_ROI(sam_predictor, image, P_boxes)
    
#     person_annotation = get_annotated_image(image, labels,P_labels,detections,p_detections)

#     # Create LocationInfo objects
#     obj_dict = get_location_info(DINO_boxes, labels, SAM_masks)
#     obj_dict.update(get_location_info(P_boxes, P_labels, P_masks))


#     counts = display_mask(SAM_masks,P_masks,P_boxes,DINO_boxes,person_annotation,output_path)

#     return obj_dict, counts,labels, P_labels


# #
# inputfile = "Frame_3hz_ARHUD/video_0311/image_0009.png"
# outputfile = "../video_0311/image_0009.png"

# # output_dir = Path(outputfile).parent
# # output_dir.mkdir(parents=True, exist_ok=True)
# obj_dict, counts,labels, P_labels = detect_road("input/video_0310/image_0005.png",output_path="../video_0310/image_0005.png")

# %%
# # Process and write results
# def analyze_road(image_path,output_path,counts, labels, P_labels,depth_flag=False):
#     image = get_cv2_image(image_path)
#     if image is None:
#         print("Error when reading ",image_path)
#         return None
    
#     depth_map = None
#     # Predict depth
#     if depth_flag:
#         depth_map = predict_depth(image_path,output_path)

#     # Analyze person location
#     p_surface_overlaps = analyze_person_location(obj_dict, depth_flag, image, depth_map)

#     write_to_txt(image_path, output_path, p_surface_overlaps,obj_dict)

#     plt.close()

# analyze_road(inputfile,outputfile,obj_dict,counts ,labels, P_labels,depth_flag=True)

# %% [markdown]
# tmp distance

# %%
DEPTH_FLAG = True
def detect_road(image_path:str,output_path:str):
    """
        This function analyzes a road scene from an image and detects various
    entities such as roads, sidewalks, and people. 
    - detection: grounding DINO model
    - segmentation:     SAM model 
    - depth prediction: DPT model 
    Detected entities are represented as LocationInfo objects and stored in a Counter.
    The function also annotates the original image with detection boxes and labels.

    Args:
        image_path (str): Path to the input image.
        output_path (str): Path to save the output image with annotations and masks.

    Returns:
        obj_dict (dict): A dictionary mapping from unique entity identifiers 
        to corresponding LocationInfo objects.

    Raises:
        Exception: If the image at the given path cannot be read or processed.

    Note:
        global variables: BOX_TRESHOLD, TEXT_TRESHOLD, PED_TRESHOLD, and DEBUG,
        need to be set prior to calling this function.
    """

    try:
        image = cv2.imread(image_path)
        if image is None:
            print(f"Image at path {image_path} could not be loaded. Skipping.")
            return None
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    except Exception as e:
        print(f"Failed to process image at {image_path}. Error: {e}")
        return None
    
    ROAD_SIDEWALK = ['road', 'sidewalk'] 
    P_CLASS     = ['person','car']
    # the person label lower gDINO's performance
    # so I split them

    # detect road and sidewalk
    detections = grounding_dino_model.predict_with_classes(
        image=image,
        classes = ROAD_SIDEWALK,
        box_threshold= BOX_TRESHOLD,
        text_threshold=TEXT_TRESHOLD
    )
    detections = nms_processing(detections)
    # detect person 
    p_detections = grounding_dino_model.predict_with_classes(
        image = image,
        classes = P_CLASS , 
        box_threshold= BOX_TRESHOLD,
        text_threshold=PED_TRESHOLD 
    )
    p_detections = nms_processing(p_detections)

    # if p_detections is None:
    #     return None
    box_annotator = sv.BoxAnnotator()
    person_annotator = sv.BoxAnnotator()

    labels = [
        f"{ROAD_SIDEWALK[class_id]} {i} {confidence:0.2f}" 
        for i, (_, _, confidence, class_id, _) in enumerate(detections)]

    if p_detections is None or all(confidence < 0.5 for _, _, confidence, _, _ in p_detections):
        return None
    else:
        P_labels = []
        for i, detection in enumerate(p_detections):
            _, _, confidence, class_id, _ = detection
            # print("classid is ",class_id)
            if class_id is None:
                continue
            label = "{0} {1} {2:.2f}".format(P_CLASS[class_id], i, confidence)
            P_labels.append(label)


    
    DINO_boxes = np.array(detections.xyxy)
    P_boxes    = np.array(p_detections.xyxy)


    annotated_frame = box_annotator.annotate(scene=image.copy(), detections=detections ,labels=labels)
    if DEBUG:
        sv.plot_image(annotated_frame, (16, 16))
    person_annotation = person_annotator.annotate(scene=annotated_frame,detections= p_detections,labels= P_labels)
    if DEBUG:
        sv.plot_image(person_annotation, (16, 16))
    # cv2.imwrite("annotated_image.jpg", annotated_frame)
    
    SAM_masks = segment_ROI(sam_predictor,image,DINO_boxes)
    P_masks = segment_ROI(sam_predictor,image,DINO_boxes)

    # Create a list of LocationInfo objects for each detected object
    obj_dict = Counter()
    
    for i, (box, label, mask) in enumerate(zip(DINO_boxes, labels, SAM_masks)):
        object_type, id, confidence   = label.split(' ')
        index = object_type +id
        obj_dict[index] =  (LocationInfo(object_type, int(id), box, mask,confidence)) 

    for i, (box, label, mask) in enumerate(zip(P_boxes, P_labels, P_masks)):
        object_type, id, confidence = label.split(' ')
        index = object_type+id
        obj_dict[index] = (LocationInfo(object_type, int(id), box, mask,confidence)) 

    if DEPTH_FLAG:
        depth_map = predict_depth(image_path,output_path)
    
    # Analyze where each person is standing
    p_surface_overlaps = []
    
    for name, person in obj_dict.items():
        if person.object_type != "person":
            continue # We only want to analyze persons
        if DEPTH_FLAG:
            person.distance = get_distance_category(depth_map,person.mask)
            person.angle   = estimate_angle(image,person)
        
        overlaps = []
        for name, surface in obj_dict.items():
            # We only want to analyze surfaces (road or sidewalk)
            if surface.object_type not in ROAD_SIDEWALK: 
                continue

            # Check if the person and the surface overlap
            overlap, _ = is_overlap(person.mask, surface.mask)
            if overlap:
                overlaps.append(surface)

        p_surface_overlaps.append((person, overlaps))


    if DEBUG:
        # Print out the analysis results
        for person, surfaces in p_surface_overlaps:
            if surfaces:
                surface_str = ', '.join([f"{surface.object_type} {surface.id}" for surface in surfaces])
                print(f"Person {person.id} is on the {surface_str}")
            else:
                print(f"Person {person.id} is not on any detected surface")

    # (i, j, k, d) = display_mask(SAM_masks,P_masks,P_boxes,DINO_boxes,person_annotation,output_path)
    

    write_to_txt(image_path, output_path, p_surface_overlaps, obj_dict)

    plt.close()
    
    # return DINO_boxes,labels,P_labels,SAM_masks,P_masks
    return obj_dict

# obj_dict= detect_road("input/scene_2.png",output_path="DINOmasked/scene_2.png")
# DINO_boxes,labels,P_labels,SAM_masks,P_masks = detect_road("input/video_0031/image_0005.png",output_path="DINOmasked/man.png")
# DINO_boxes,labels,P_labels,SAM_masks,P_masks = detect_road("JAAD_seg_by_sec/video_0268/image_0001.png",output_path="DINOmasked/video_0268/image_0001.png")
# DINO_boxes,labels,P_labels,SAM_masks,P_masks = detect_road("JAAD_seg_by_sec/video_0268/image_0003.png",output_path="DINOmasked/video_0268/image_0003.png")
# obj_dict,labels,p_labels =  detect_road("JAAD_seg_by_sec/video_0060/image_0005.png",output_path="SSS.png" )# "DINOmasked/video_0060/image_0005.png")
obj_dict =  detect_road("input/video_2hz_output/video_0001/image_0008.png",output_path="SSS.png" )# "DINOmasked/video_0060/image_0005.png")

# %% [markdown]
# ## File IO logic
# the following code demonstrate how is the IO logic organized
#
# For the sake of fast file inquiry, I used library: Path() and os
#
# Feel free to modify this part if you need, just in case the content is too big, which may crash the kernel

# %%
image_path = "input/video_0268/image_0001.png"
output_path = "DINOmasked/video_0018/man.png"

output_dir = Path(output_path).parent

print(output_dir)
img_name = image_path[-8:-4]
txt_name = "Info_Video_"+ str(output_dir)[-4:] +".txt"
txt_path = os.path.join(output_dir, txt_name) 
print(txt_path)
# Out:
# DINOmasked/video_0018
# DINOmasked/video_0018/Info_Video_0018.txt

# %%
# STOP RUNNING THE MAIN PROGRAM

# %% [markdown]
# ## Main Function

# %%
input_dir = Path("input/bdd_2hz_output/") # contain many folders  JAAD_seg_by_sec
output_dir = Path('bdd_vision_output')
output_dir.mkdir(parents=True, exist_ok=True)

print("===== Start =====")
i = 1
# Use rglob to recursively find all image files
for image_path in input_dir.rglob('*'):
    if is_image_file(str(image_path)):
        relative_path = image_path.relative_to(input_dir)

        output_path = output_dir / relative_path
        output_path.parent.mkdir(parents=True,exist_ok=True)

        if False: #output_path.exists():
            print(f"Already scanned {output_path}, next one")
            continue
        else:
            print("Processing: ", i)
            i += 1
            # print(f"Image path: {os.path.basename(str(output_path))}")
            print(f"Scanning {output_path}...")
            result = detect_road(str(image_path),str(output_path))

            if result is not None:
                print(f"Detected: {image_path}") 
            else: 
                print( "failed to detect result")

print("===== END =====")
# Out:
# ===== Start =====
# Processing:  1
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0001.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0001.png
# Processing:  2
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0002.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0002.png
# Processing:  3
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0003.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0003.png
# Processing:  4
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0004.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0004.png
# Processing:  5
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0005.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0005.png
# Processing:  6
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0006.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0006.png
# Processing:  7
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0007.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0007.png
# Processing:  8
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0008.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0008.png
# Processing:  9
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0009.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0009.png
# Processing:  10
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0010.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0010.png
# Processing:  11
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0011.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0011.png
# Processing:  12
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0012.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0012.png
# Processing:  13
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0013.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0013.png
# Processing:  14
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0014.png...
# Detected: input/bdd_2hz_output/b1c9c847-3bda4659/image_0014.png
# Processing:  15
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0015.png...
# failed to detect result
# Processing:  16
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0016.png...
# failed to detect result
# Processing:  17
# Scanning bdd_vision_output/b1c9c847-3bda4659/image_0017.png...
# failed to detect result
# Processing:  18
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0001.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0001.png
# Processing:  82
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0002.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0002.png
# Processing:  83
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0003.png...
# failed to detect result
# Processing:  84
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0004.png...
# failed to detect result
# Processing:  85
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0005.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0005.png
# Processing:  86
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0006.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0006.png
# Processing:  87
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0007.png...
# failed to detect result
# Processing:  88
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0008.png...
# failed to detect result
# Processing:  89
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0009.png...
# failed to detect result
# Processing:  90
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0010.png...
# failed to detect result
# Processing:  91
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0011.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0011.png
# Processing:  92
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0012.png...
# failed to detect result
# Processing:  93
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0013.png...
# failed to detect result
# Processing:  94
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0014.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0014.png
# Processing:  95
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0015.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0015.png
# Processing:  96
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0016.png...
# failed to detect result
# Processing:  97
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0017.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0017.png
# Processing:  98
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0018.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0018.png
# Processing:  99
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0019.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0019.png
# Processing:  100
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0020.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0020.png
# Processing:  101
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0021.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0021.png
# Processing:  102
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0022.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0022.png
# Processing:  103
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0023.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0023.png
# Processing:  104
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0024.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0024.png
# Processing:  105
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0025.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0025.png
# Processing:  106
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0026.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0026.png
# Processing:  107
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0027.png...
# failed to detect result
# Processing:  108
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0028.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0028.png
# Processing:  109
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0029.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0029.png
# Processing:  110
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0030.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0030.png
# Processing:  111
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0031.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0031.png
# Processing:  112
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0032.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0032.png
# Processing:  113
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0033.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0033.png
# Processing:  114
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0034.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0034.png
# Processing:  115
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0035.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0035.png
# Processing:  116
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0036.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0036.png
# Processing:  117
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0037.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0037.png
# Processing:  118
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0038.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0038.png
# Processing:  119
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0039.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0039.png
# Processing:  120
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0040.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0040.png
# Processing:  121
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0041.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0041.png
# Processing:  122
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0042.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0042.png
# Processing:  123
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0043.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0043.png
# Processing:  124
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0044.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0044.png
# Processing:  125
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0045.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0045.png
# Processing:  126
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0046.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0046.png
# Processing:  127
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0047.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0047.png
# Processing:  128
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0048.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0048.png
# Processing:  129
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0049.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0049.png
# Processing:  130
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0050.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0050.png
# Processing:  131
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0051.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0051.png
# Processing:  132
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0052.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0052.png
# Processing:  133
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0053.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0053.png
# Processing:  134
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0054.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0054.png
# Processing:  135
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0055.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0055.png
# Processing:  136
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0056.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0056.png
# Processing:  137
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0057.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0057.png
# Processing:  138
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0058.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0058.png
# Processing:  139
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0059.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0059.png
# Processing:  140
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0060.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0060.png
# Processing:  141
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0061.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0061.png
# Processing:  142
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0062.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0062.png
# Processing:  143
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0063.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0063.png
# Processing:  144
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0064.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0064.png
# Processing:  145
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0065.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0065.png
# Processing:  146
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0066.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0066.png
# Processing:  147
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0067.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0067.png
# Processing:  148
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0068.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0068.png
# Processing:  149
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0069.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0069.png
# Processing:  150
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0070.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0070.png
# Processing:  151
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0071.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0071.png
# Processing:  152
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0072.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0072.png
# Processing:  153
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0073.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0073.png
# Processing:  154
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0074.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0074.png
# Processing:  155
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0075.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0075.png
# Processing:  156
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0076.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0076.png
# Processing:  157
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0077.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0077.png
# Processing:  158
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0078.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0078.png
# Processing:  159
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0079.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0079.png
# Processing:  160
# Scanning bdd_vision_output/b1d10d08-c35503b8/image_0080.png...
# Detected: input/bdd_2hz_output/b1d10d08-c35503b8/image_0080.png
# Processing:  161
# Scanning bdd_vision_output/b1d22ed6-f1cac061/image_0001.png...
# Detected: input/bdd_2hz_output/b1d22ed6-f1cac061/image_0001.png
# Detected: input/bdd_2hz_output/b1dac7f7-6b2e0382/image_0074.png
# Processing:  275
# Scanning bdd_vision_output/b1dac7f7-6b2e0382/image_0075.png...
# Detected: input/bdd_2hz_output/b1dac7f7-6b2e0382/image_0075.png
# Processing:  276
# Scanning bdd_vision_output/b1dac7f7-6b2e0382/image_0076.png...
# Detected: input/bdd_2hz_output/b1dac7f7-6b2e0382/image_0076.png
# Processing:  277
# Scanning bdd_vision_output/b1dac7f7-6b2e0382/image_0077.png...
# Detected: input/bdd_2hz_output/b1dac7f7-6b2e0382/image_0077.png
# Processing:  278
# Scanning bdd_vision_output/b1dac7f7-6b2e0382/image_0078.png...
# Detected: input/bdd_2hz_output/b1dac7f7-6b2e0382/image_0078.png
# Processing:  279
# Scanning bdd_vision_output/b1dac7f7-6b2e0382/image_0079.png...
# Detected: input/bdd_2hz_output/b1dac7f7-6b2e0382/image_0079.png
# Processing:  280
# Scanning bdd_vision_output/b1dac7f7-6b2e0382/image_0080.png...
# Detected: input/bdd_2hz_output/b1dac7f7-6b2e0382/image_0080.png
# Processing:  281
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0001.png...
# failed to detect result
# Processing:  282
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0002.png...
# failed to detect result
# Processing:  283
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0003.png...
# failed to detect result
# Processing:  284
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0004.png...
# failed to detect result
# Processing:  285
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0005.png...
# failed to detect result
# Processing:  286
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0006.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0006.png
# Processing:  287
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0007.png...
# failed to detect result
# Processing:  288
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0008.png...
# failed to detect result
# Processing:  289
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0009.png...
# failed to detect result
# Processing:  290
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0010.png...
# failed to detect result
# Processing:  291
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0011.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0011.png
# Processing:  292
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0012.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0012.png
# Processing:  293
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0013.png...
# failed to detect result
# Processing:  294
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0014.png...
# failed to detect result
# Processing:  295
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0015.png...
# failed to detect result
# Processing:  296
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0016.png...
# failed to detect result
# Processing:  297
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0017.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0017.png
# Processing:  298
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0018.png...
# Processing:  340
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0060.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0060.png
# Processing:  341
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0061.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0061.png
# Processing:  342
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0062.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0062.png
# Processing:  343
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0063.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0063.png
# Processing:  344
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0064.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0064.png
# Processing:  345
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0065.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0065.png
# Processing:  346
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0066.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0066.png
# Processing:  347
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0067.png...
# Detected: input/bdd_2hz_output/b1f4491b-33824f31/image_0067.png
# Processing:  348
# Scanning bdd_vision_output/b1f4491b-33824f31/image_0068.png...
# ...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0004.png
# Processing:  969
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0005.png...
# failed to detect result
# Processing:  970
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0006.png...
# failed to detect result
# Processing:  971
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0007.png...
# failed to detect result
# Processing:  972
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0008.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0008.png
# Processing:  973
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0009.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0009.png
# Processing:  974
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0010.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0010.png
# Processing:  975
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0011.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0011.png
# Processing:  976
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0012.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0012.png
# Processing:  977
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0013.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0013.png
# Processing:  978
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0014.png...
# failed to detect result
# Processing:  979
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0015.png...
# failed to detect result
# Processing:  980
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0016.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0016.png
# Processing:  981
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0017.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0017.png
# Processing:  982
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0018.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0018.png
# Processing:  983
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0019.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0019.png
# Processing:  984
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0020.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0020.png
# Processing:  985
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0021.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0021.png
# Processing:  986
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0022.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0022.png
# Processing:  987
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0023.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0023.png
# Processing:  988
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0024.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0024.png
# Processing:  989
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0025.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0025.png
# Processing:  990
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0026.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0026.png
# Processing:  991
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0027.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0027.png
# Processing:  992
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0028.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0028.png
# Processing:  993
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0029.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0029.png
# Processing:  994
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0030.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0030.png
# Processing:  995
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0031.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0031.png
# Processing:  996
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0032.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0032.png
# Processing:  997
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0033.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0033.png
# Processing:  998
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0034.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0034.png
# Processing:  999
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0035.png...
# failed to detect result
# Processing:  1000
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0036.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0036.png
# Processing:  1001
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0037.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0037.png
# Processing:  1002
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0038.png...
# failed to detect result
# Processing:  1003
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0039.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0039.png
# Processing:  1004
# Scanning bdd_vision_output/cd17ff29-f393274e/image_0040.png...
# Detected: input/bdd_2hz_output/cd17ff29-f393274e/image_0040.png
# Processing:  1005
# Scanning bdd_vision_output/cd26264b-22001629/image_0001.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0001.png
# Processing:  1006
# Scanning bdd_vision_output/cd26264b-22001629/image_0002.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0002.png
# Processing:  1007
# Scanning bdd_vision_output/cd26264b-22001629/image_0003.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0003.png
# Processing:  1008
# Scanning bdd_vision_output/cd26264b-22001629/image_0004.png...
# failed to detect result
# Processing:  1009
# Scanning bdd_vision_output/cd26264b-22001629/image_0005.png...
# failed to detect result
# Processing:  1010
# Scanning bdd_vision_output/cd26264b-22001629/image_0006.png...
# failed to detect result
# Processing:  1011
# Scanning bdd_vision_output/cd26264b-22001629/image_0007.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0007.png
# Processing:  1012
# Scanning bdd_vision_output/cd26264b-22001629/image_0008.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0008.png
# Processing:  1013
# Scanning bdd_vision_output/cd26264b-22001629/image_0009.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0009.png
# Processing:  1014
# Scanning bdd_vision_output/cd26264b-22001629/image_0010.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0010.png
# Processing:  1015
# Scanning bdd_vision_output/cd26264b-22001629/image_0011.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0011.png
# Processing:  1016
# Scanning bdd_vision_output/cd26264b-22001629/image_0012.png...
# failed to detect result
# Processing:  1017
# Scanning bdd_vision_output/cd26264b-22001629/image_0013.png...
# failed to detect result
# Processing:  1018
# Scanning bdd_vision_output/cd26264b-22001629/image_0014.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0014.png
# Processing:  1019
# Scanning bdd_vision_output/cd26264b-22001629/image_0015.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0015.png
# Processing:  1020
# Scanning bdd_vision_output/cd26264b-22001629/image_0016.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0016.png
# Processing:  1021
# Scanning bdd_vision_output/cd26264b-22001629/image_0017.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0017.png
# Processing:  1022
# Scanning bdd_vision_output/cd26264b-22001629/image_0018.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0018.png
# Processing:  1023
# Scanning bdd_vision_output/cd26264b-22001629/image_0019.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0019.png
# Processing:  1024
# Scanning bdd_vision_output/cd26264b-22001629/image_0020.png...
# failed to detect result
# Processing:  1025
# Scanning bdd_vision_output/cd26264b-22001629/image_0021.png...
# failed to detect result
# Processing:  1026
# Scanning bdd_vision_output/cd26264b-22001629/image_0022.png...
# failed to detect result
# Processing:  1027
# Scanning bdd_vision_output/cd26264b-22001629/image_0023.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0023.png
# Processing:  1028
# Scanning bdd_vision_output/cd26264b-22001629/image_0024.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0024.png
# Processing:  1029
# Scanning bdd_vision_output/cd26264b-22001629/image_0025.png...
# failed to detect result
# Processing:  1030
# Scanning bdd_vision_output/cd26264b-22001629/image_0026.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0026.png
# Processing:  1031
# Scanning bdd_vision_output/cd26264b-22001629/image_0027.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0027.png
# Processing:  1032
# Scanning bdd_vision_output/cd26264b-22001629/image_0028.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0028.png
# Processing:  1033
# Scanning bdd_vision_output/cd26264b-22001629/image_0029.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0029.png
# Processing:  1034
# Scanning bdd_vision_output/cd26264b-22001629/image_0030.png...
# failed to detect result
# Processing:  1035
# Scanning bdd_vision_output/cd26264b-22001629/image_0031.png...
# failed to detect result
# Processing:  1036
# Scanning bdd_vision_output/cd26264b-22001629/image_0032.png...
# failed to detect result
# Processing:  1037
# Scanning bdd_vision_output/cd26264b-22001629/image_0033.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0033.png
# Processing:  1038
# Scanning bdd_vision_output/cd26264b-22001629/image_0034.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0034.png
# Processing:  1039
# Scanning bdd_vision_output/cd26264b-22001629/image_0035.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0035.png
# Processing:  1040
# Scanning bdd_vision_output/cd26264b-22001629/image_0036.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0036.png
# Processing:  1041
# Scanning bdd_vision_output/cd26264b-22001629/image_0037.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0037.png
# Processing:  1042
# Scanning bdd_vision_output/cd26264b-22001629/image_0038.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0038.png
# Processing:  1043
# Scanning bdd_vision_output/cd26264b-22001629/image_0039.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0039.png
# Processing:  1044
# Scanning bdd_vision_output/cd26264b-22001629/image_0040.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0040.png
# Processing:  1045
# Scanning bdd_vision_output/cd26264b-22001629/image_0041.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0041.png
# Processing:  1046
# Scanning bdd_vision_output/cd26264b-22001629/image_0042.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0042.png
# Processing:  1047
# Scanning bdd_vision_output/cd26264b-22001629/image_0043.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0043.png
# Processing:  1048
# Scanning bdd_vision_output/cd26264b-22001629/image_0044.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0044.png
# Processing:  1049
# Scanning bdd_vision_output/cd26264b-22001629/image_0045.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0045.png
# Processing:  1050
# Scanning bdd_vision_output/cd26264b-22001629/image_0046.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0046.png
# Processing:  1051
# Scanning bdd_vision_output/cd26264b-22001629/image_0047.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0047.png
# Processing:  1052
# Scanning bdd_vision_output/cd26264b-22001629/image_0048.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0048.png
# Processing:  1053
# Scanning bdd_vision_output/cd26264b-22001629/image_0049.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0049.png
# Processing:  1054
# Scanning bdd_vision_output/cd26264b-22001629/image_0050.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0050.png
# Processing:  1055
# Scanning bdd_vision_output/cd26264b-22001629/image_0051.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0051.png
# Processing:  1056
# Scanning bdd_vision_output/cd26264b-22001629/image_0052.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0052.png
# Processing:  1057
# Scanning bdd_vision_output/cd26264b-22001629/image_0053.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0053.png
# Processing:  1058
# Scanning bdd_vision_output/cd26264b-22001629/image_0054.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0054.png
# Processing:  1059
# Scanning bdd_vision_output/cd26264b-22001629/image_0055.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0055.png
# Processing:  1060
# Scanning bdd_vision_output/cd26264b-22001629/image_0056.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0056.png
# Processing:  1061
# Scanning bdd_vision_output/cd26264b-22001629/image_0057.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0057.png
# Processing:  1062
# Scanning bdd_vision_output/cd26264b-22001629/image_0058.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0058.png
# Processing:  1063
# Scanning bdd_vision_output/cd26264b-22001629/image_0059.png...
# failed to detect result
# Processing:  1064
# Scanning bdd_vision_output/cd26264b-22001629/image_0060.png...
# failed to detect result
# Processing:  1065
# Scanning bdd_vision_output/cd26264b-22001629/image_0061.png...
# failed to detect result
# Processing:  1066
# Scanning bdd_vision_output/cd26264b-22001629/image_0062.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0062.png
# Processing:  1067
# Scanning bdd_vision_output/cd26264b-22001629/image_0063.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0063.png
# Processing:  1068
# Scanning bdd_vision_output/cd26264b-22001629/image_0064.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0064.png
# Processing:  1069
# Scanning bdd_vision_output/cd26264b-22001629/image_0065.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0065.png
# Processing:  1070
# Scanning bdd_vision_output/cd26264b-22001629/image_0066.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0066.png
# Processing:  1071
# Scanning bdd_vision_output/cd26264b-22001629/image_0067.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0067.png
# Processing:  1072
# Scanning bdd_vision_output/cd26264b-22001629/image_0068.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0068.png
# Processing:  1073
# Scanning bdd_vision_output/cd26264b-22001629/image_0069.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0069.png
# Processing:  1074
# Scanning bdd_vision_output/cd26264b-22001629/image_0070.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0070.png
# Processing:  1075
# Scanning bdd_vision_output/cd26264b-22001629/image_0071.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0071.png
# Processing:  1076
# Scanning bdd_vision_output/cd26264b-22001629/image_0072.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0072.png
# Processing:  1077
# Scanning bdd_vision_output/cd26264b-22001629/image_0073.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0073.png
# Processing:  1078
# Scanning bdd_vision_output/cd26264b-22001629/image_0074.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0074.png
# Processing:  1079
# Scanning bdd_vision_output/cd26264b-22001629/image_0075.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0075.png
# Processing:  1080
# Scanning bdd_vision_output/cd26264b-22001629/image_0076.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0076.png
# Processing:  1081
# Scanning bdd_vision_output/cd26264b-22001629/image_0077.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0077.png
# Processing:  1082
# Scanning bdd_vision_output/cd26264b-22001629/image_0078.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0078.png
# Processing:  1083
# Scanning bdd_vision_output/cd26264b-22001629/image_0079.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0079.png
# Processing:  1084
# Scanning bdd_vision_output/cd26264b-22001629/image_0080.png...
# Detected: input/bdd_2hz_output/cd26264b-22001629/image_0080.png
# ===== END =====

# %%
STOP RUNNING PROGRAM
# Out:
#   Cell In[20], line 1
#     STOP RUNNING PROGRAM
#          ^
# SyntaxError: invalid syntax

# %%
from scipy.spatial import distance_matrix
from scipy.optimize import linear_sum_assignment

def video_diff(result_old: dict, result_new: dict):
    """
    Compares two dictionaries of LocationInfo objects representing consecutive frames.
    For each object that appears in both frames, calculates the distance moved.

    Parameters:
    - result_old: A dictionary of LocationInfo objects from the previous frame.
    - result_new: A dictionary of LocationInfo objects from the current frame.

    Returns:
    - A dictionary mapping each object id to the distance it moved.
    """
    movement_dict = {}

    old_people = [obj for obj in result_old.values() if obj.object_type == 'person']
    new_people = [obj for obj in result_new.values() if obj.object_type == 'person']

    old_centroids = [[(obj.box[0] + obj.box[2]) / 2, (obj.box[1] + obj.box[3]) / 2] for obj in old_people]
    new_centroids = [[(obj.box[0] + obj.box[2]) / 2, (obj.box[1] + obj.box[3]) / 2] for obj in new_people]

    # calculate the distance matrix between all pairs of centroids
    dist_mat = distance_matrix(old_centroids, new_centroids)
    
    # apply the Hungarian algorithm to find the optimal assignment
    row_inds, col_inds = linear_sum_assignment(dist_mat)

    for row_ind, col_ind in zip(row_inds, col_inds):
        distance = dist_mat[row_ind, col_ind]
        # here we make a new key for each matched pair
        movement_dict[(old_people[row_ind].id, new_people[col_ind].id)] = distance

    return movement_dict

# %%
def main(input_dir_path: str, output_dir_path: str):
    input_dir = Path(input_dir_path) 
    output_dir = Path(output_dir_path)
    output_dir.mkdir(parents=True, exist_ok=True)

    print("===== Start =====")
    image_paths = sorted(input_dir.rglob('*'), key=lambda x: x.stem)  # Use rglob to recursively find all image files and sort them
    
    # Check if there is at least one image in the directory
    if not image_paths:
        print(f"No images found in the directory {input_dir_path}")
        return

    result_old = None  # Initialize the variable for the first iteration

    for i, image_path in enumerate(image_paths, start=1):
        if is_image_file(str(image_path)):
            relative_path = image_path.relative_to(input_dir)

            output_path = output_dir / relative_path
            output_path.parent.mkdir(parents=True,exist_ok=True)

            # if output_path.exists():
            #     print(f"Already scanned {output_path}, moving to the next one")
            #     continue

            print(f"Processing image {i}: {os.path.basename(str(image_path))}")

            try:
                result_new = detect_road(str(image_path), str(output_path))
                if result_new is not None:
                    print(f"Detected objects in {image_path}")

                    # Compute and compare the speed only if there is a previous frame to compare with
                    if result_old is not None:
                        movedict = video_diff(result_old, result_new)
                        print(movedict)
                    result_old = result_new
                else: 
                    print(f"Failed to detect objects in {image_path}")

            except Exception as e:
                print(f"An error occurred while processing {image_path}: {e}")
                continue
    print("===== END =====")
    return movedict

movedict = main("Frame_3hz_ARHUD/video_0311/", "../speed")

# %%
movedict[(0,1)]

# %%
import os
import zipfile
from datetime import datetime

def zip_vision_files(root_folder, output_zip_file, zip_subfolder):
    # Create a ZIP file
    with zipfile.ZipFile(output_zip_file, 'w') as zipf:
        # Walk through the root folder and its subdirectories
        for root, dirs, files in os.walk(root_folder):
            for file in files:
                if file.startswith("Info_Video_") and file.endswith(".txt"):
                    file_path = os.path.join(root, file)
                    # Define the path inside the ZIP file
                    zip_path = os.path.join(zip_subfolder, os.path.basename(file_path))
                    # Add the file to the ZIP with the defined path
                    zipf.write(file_path, zip_path)

# Define the root folder where the data is stored
root_folder = 'bdd_vision_output'

# Get today's date in the format 0813
date_str = datetime.now().strftime('%m%d')

# Define the name of the ZIP file
output_zip_file = f'Vision_Output_{date_str}.zip'

# Define the subfolder inside the ZIP file
zip_subfolder = f'Vision_Output_{date_str}'

# Create the ZIP file
zip_vision_files(root_folder, output_zip_file, zip_subfolder)

print(f"Created ZIP file: {output_zip_file}")
# Out:
# Created ZIP file: Vision_Output_0815.zip
